# %% [markdown]
# # L-Système - Zone de test

# %% [markdown]
# - autair : Silanoc
# - date : 2024-02-06

# %% [markdown]
# ## Typage avec mypy

# %%
import mypy_extensions

# %%
# !ls
# Out:
# 'courbe de Koch 1.py'  'image Fractale'   __pycache__	   venv_l_systeme
# 'courbe de Koch 2.py'   plante_1_1.py	  README.md
#  generateur.py	       'plante 1.py'	  Untitled.ipynb

# %% [markdown]
# ### Tester 1 seul fichier

# %%
# !mypy generateur.py
# Out:
# generateur.py:105: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:106: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:107: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:108: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:109: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:113: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# ...

# %% [markdown]
# ### tous tester

# %%
# !mypy *.py
# Out:
# generateur.py:105: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:106: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:107: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:108: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:109: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# generateur.py:113: note: By default the bodies of untyped functions are not checked, consider using --check-untyped-defs  [annotation-unchecked]
# ...
